# %% [markdown]
# <a href="https://colab.research.google.com/github/Dsai9876/Hello/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install detecto

# %%
from detecto import core, utils, visualize
 
dataset = core.Dataset('/content/drive/My Drive/data')
model = core.Model(['gun'])
 
model.fit(dataset)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# ...
# /usr/local/lib/python3.6/dist-packages/torchvision/ops/boxes.py:101: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   keep = keep.nonzero().squeeze(1)

# %%
image = utils.read_image('/content/drive/My Drive/data/images (7).jpeg')
predictions = model.predict(image)
 
 
 
 
# predictions format: (labels, boxes, scores)
 
labels, boxes, scores = predictions
 
# ['alien', 'bat', 'bat']
print(labels) 
 
#           xmin       ymin       xmax       ymax
# tensor([[ 569.2125,  203.6702, 1003.4383,  658.1044],
#         [ 276.2478,  144.0074,  579.6044,  508.7444],
#         [ 277.2929,  162.6719,  627.9399,  51841]])
print(boxes)
 
# tensor([0.9952, 0.9837, 0.5153])
print(scores)
# Out:
# ['gun', 'gun', 'gun', 'gun', 'gun', 'gun', 'gun', 'gun']
# tensor([[ 41.3293,  14.8236, 598.2549, 339.0000],
#         [157.4877,  35.5581, 630.0000, 238.5560],
#         [ 43.7655,   8.9430, 267.5056, 311.8395],
#         [125.2567,   4.6112, 392.8745, 303.5128],
#         [324.5502,   2.5592, 580.7966, 329.7369],
#         [204.4316,  74.9216, 412.3003, 339.0000],
#         [251.3821,   8.7645, 488.8699, 339.0000],
#         [113.9050, 103.8284, 494.2411, 329.4774]])
# tensor([0.8359, 0.5042, 0.2112, 0.1559, 0.1177, 0.0780, 0.0598, 0.0537])

# %%
visualize.show_labeled_image(image, boxes[3], labels[3])

# %%
import dill
dill.dump_session('notebook_env.db')

# %%
 import dill
dill.load_session('notebook_env.db')
